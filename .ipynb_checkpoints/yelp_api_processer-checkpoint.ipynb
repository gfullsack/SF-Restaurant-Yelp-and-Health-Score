# %%
# Imports
import pandas as pd
import requests
from api_keys import api_key

# %%
# Configure API URI
uri = 'https://api.yelp.com/v3/businesses/search'

payload = {
    'term': 'restaurants',
    'location': 'san francisco',
    'limit': 50,
    'offset': 0
}

headers = {
    'Authorization': f"Bearer {api_key}"
    
}

# %%
api_key
# Out:
# 'hrN8jkRqmK98cAM_adsRKgoePPsCnGCugW0zSZmL_rBS4HUKz8QXF0zP2O7OPgE_LzIKlF-_rBKkoZg_L4e6ZwUbRQ1IGLzLR8Z2VL24fdKvD6llHNX6um5_m8FIXXYx'

# %%
# Perform API Request for restaurants in SF
# https://api.yelp.com/v3/businesses/search?term=restaurants&location=san francisco

# %%
response = requests.get(uri, params=payload, headers=headers)

# %%
response.json()
# Out:
# {'businesses': [{'id': 'f-m7-hyFzkf0HSEeQ2s-9A',
#    'alias': 'fog-harbor-fish-house-san-francisco-2',
#    'name': 'Fog Harbor Fish House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Lv7tIRX3Bim9bKqtWifmNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fog-harbor-fish-house-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 5531,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.809041, 'longitude': -122.410233},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': 'Pier 39',
#     'address2': 'Ste A-202',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94133',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['Pier 39', 'Ste A-202', 'San Francisco, CA 94133']},
#    'phone': '+14154212442',
#    'display_phone': '(415) 421-2442',
#    'distance': 5827.740044156521},
#   {'id': 'ZoZjbOYR-apY8XvommlNUA',
#    'alias': 'the-house-san-francisco',
#    'name': 'The House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UzrNIkdGTZ1-cXuQDsKUmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-house-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 4650,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.79851, 'longitude': -122.40706},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '1230 Grant Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94133',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1230 Grant Ave', 'San Francisco, CA 94133']},
#    'phone': '+14159868612',
#    'display_phone': '(415) 986-8612',
#    'distance': 4911.928931733509},
#   {'id': 'HHtpR0RslupSQ99GIIwW5A',
#    'alias': 'marufuku-ramen-sf-san-francisco',
#    'name': 'Marufuku Ramen SF',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2lUFO5HWD7_RLDWlT5Nvuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marufuku-ramen-sf-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2404,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.785155, 'longitude': -122.432075},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1581 Webster St',
#     'address2': 'Ste 235',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1581 Webster St',
#      'Ste 235',
#      'San Francisco, CA 94115']},
#    'phone': '+14158729786',
#    'display_phone': '(415) 872-9786',
#    'distance': 2724.336436836609},
#   {'id': '4KfQnlcSu4bbTqnvGdGptw',
#    'alias': 'beretta-san-francisco',
#    'name': 'Beretta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RsCeyBgtnXpmN9YTKEIvWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beretta-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 3500,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.75384, 'longitude': -122.42055},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1199 Valencia St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1199 Valencia St', 'San Francisco, CA 94110']},
#    'phone': '+14156951199',
#    'display_phone': '(415) 695-1199',
#    'distance': 1591.3097447927287},
#   {'id': '8kck3-K4zYKTJbJko0JlXQ',
#    'alias': 'farmhouse-kitchen-thai-cuisine-san-francisco',
#    'name': 'Farmhouse Kitchen Thai Cuisine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AC0JE-nnMd-Ai3SlA7IPfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farmhouse-kitchen-thai-cuisine-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2034,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7602179, 'longitude': -122.4110749},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '710 Florida St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['710 Florida St', 'San Francisco, CA 94110']},
#    'phone': '+14158142920',
#    'display_phone': '(415) 814-2920',
#    'distance': 2228.504131085978},
#   {'id': 'KkAVX3Wb7E3lP5F_f_8pXg',
#    'alias': 'liholiho-yacht-club-san-francisco-2',
#    'name': 'Liholiho Yacht Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FK2X98w6z5naJyiQjsGTNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liholiho-yacht-club-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2203,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.78818, 'longitude': -122.41458},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '871 Sutter St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['871 Sutter St', 'San Francisco, CA 94109']},
#    'phone': '+14154405446',
#    'display_phone': '(415) 440-5446',
#    'distance': 3596.036080023175},
#   {'id': '1hMD7RQogPDWpE-p3LKjXA',
#    'alias': 'loló-san-francisco-4',
#    'name': 'Loló',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-_hqewRYasro3NpC-v4Fug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lol%C3%B3-san-francisco-4?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2072,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7573462, 'longitude': -122.4214034},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '974 Valencia St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['974 Valencia St', 'San Francisco, CA 94110']},
#    'phone': '+14156435656',
#    'display_phone': '(415) 643-5656',
#    'distance': 1380.24804973913},
#   {'id': 'QQkroHtwS96-dzMpT4a-DA',
#    'alias': 'delarosa-san-francisco',
#    'name': 'Delarosa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ADrarUkNN9kuVbyPae0HyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/delarosa-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1454,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.800287, 'longitude': -122.439110224537},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '2175 Chestnut St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2175 Chestnut St', 'San Francisco, CA 94123']},
#    'phone': '+14156737100',
#    'display_phone': '(415) 673-7100',
#    'distance': 4385.946516592388},
#   {'id': 'wxzx3duu1c0CcomzEOvfOQ',
#    'alias': 'the-front-porch-san-francisco',
#    'name': 'The Front Porch',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0fmMVyqSKOMIqtkQksUTUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-front-porch-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2719,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7438, 'longitude': -122.422035},
#    'transactions': ['restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '65 29th St',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['65 29th St', 'Ste A', 'San Francisco, CA 94110']},
#    'phone': '+14156957800',
#    'display_phone': '(415) 695-7800',
#    'distance': 2285.237602234066},
#   {'id': 'jqEpBbf_qNfWuz_GBkwCjw',
#    'alias': 'scomas-restaurant-san-francisco-3',
#    'name': "Scoma's Restaurant",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5ZqAdIz1IhUDlmK6qP3WvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scomas-restaurant-san-francisco-3?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 3567,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.808944, 'longitude': -122.418462},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '1965 Al Scoma Way',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94133',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1965 Al Scoma Way', 'San Francisco, CA 94133']},
#    'phone': '+14157714383',
#    'display_phone': '(415) 771-4383',
#    'distance': 5571.204721217614},
#   {'id': 'bH8FgQYhxkj5qQ4wL7vPFA',
#    'alias': 'tuba-authentic-turkish-restaurant-san-francisco',
#    'name': 'Tuba Authentic Turkish Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tglhXFpXHEym_CKoj6v_CQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tuba-authentic-turkish-restaurant-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 987,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.7548912, 'longitude': -122.4228895},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1007 Guerrero St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1007 Guerrero St', 'San Francisco, CA 94110']},
#    'phone': '+14158268822',
#    'display_phone': '(415) 826-8822',
#    'distance': 1366.338499605357},
#   {'id': 'DGyoVB9PdI9_jw0CNi_OPg',
#    'alias': 'suppenküche-san-francisco-2',
#    'name': 'Suppenküche',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5mt7G1S_hFYv3rYIl7v2lQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/suppenk%C3%BCche-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 3086,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7762603759766,
#     'longitude': -122.426391601562},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '525 Laguna St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['525 Laguna St', 'San Francisco, CA 94102']},
#    'phone': '+14152529289',
#    'display_phone': '(415) 252-9289',
#    'distance': 1919.7883063813613},
#   {'id': 'PiY8Ks8KWlIcAvqNdMjvBA',
#    'alias': 'izakaya-kou-san-francisco-2',
#    'name': 'Izakaya KOU',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/a_VbSN_CoGYRiHCECSGpeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-kou-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 758,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7840954508032,
#     'longitude': -122.432791119359},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1560 Fillmore St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1560 Fillmore St', 'San Francisco, CA 94115']},
#    'phone': '+14154419294',
#    'display_phone': '(415) 441-9294',
#    'distance': 2599.2216991699147},
#   {'id': '8dUaybEPHsZMgr1iKgqgMQ',
#    'alias': 'sotto-mare-oysteria-and-seafood-san-francisco',
#    'name': 'Sotto Mare Oysteria & Seafood',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Efr_0zx4ID9jla5kxuIMNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sotto-mare-oysteria-and-seafood-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 3541,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.79979, 'longitude': -122.40834},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '552 Green St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94133',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['552 Green St', 'San Francisco, CA 94133']},
#    'phone': '+14153983181',
#    'display_phone': '(415) 398-3181',
#    'distance': 4980.8804673363975},
#   {'id': 'eYXwVR4mMAjzkJnm5wneHQ',
#    'alias': 'burma-superstar-san-francisco-2',
#    'name': 'Burma Superstar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CQljYYJrIWarCxsz02s-7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burma-superstar-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 6619,
#    'categories': [{'alias': 'burmese', 'title': 'Burmese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.782787322998,
#     'longitude': -122.462539672852},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '309 Clement St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94118',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['309 Clement St', 'San Francisco, CA 94118']},
#    'phone': '+14153872147',
#    'display_phone': '(415) 387-2147',
#    'distance': 3346.3513929682595},
#   {'id': 'M0JTO3oyu6gxh1mfFjU-dA',
#    'alias': 'san-tung-san-francisco-2',
#    'name': 'San Tung',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LTtoZ25m8FX1UV37asnTCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-tung-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 6617,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.76367, 'longitude': -122.46896},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1031 Irving St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94122',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1031 Irving St', 'San Francisco, CA 94122']},
#    'phone': '+14152420828',
#    'display_phone': '(415) 242-0828',
#    'distance': 2877.9920007894843},
#   {'id': 'J7_-faNq_Ag9qTOlDn81Pw',
#    'alias': 'starbelly-san-francisco',
#    'name': 'Starbelly',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IQcRlC75Lea8bqgHpJ8Usg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/starbelly-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1776,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.764096, 'longitude': -122.432574},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3583 16th St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3583 16th St', 'San Francisco, CA 94114']},
#    'phone': '+14152527500',
#    'display_phone': '(415) 252-7500',
#    'distance': 492.2021957684228},
#   {'id': 'TCaagQVqECB97vJAs4t9Mg',
#    'alias': 'barrel-head-brewhouse-san-francisco-5',
#    'name': 'Barrel Head Brewhouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2ANEMUaKPlN3b35N2bDeVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrel-head-brewhouse-san-francisco-5?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 521,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7757521780078,
#     'longitude': -122.446032238623},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1785 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1785 Fulton St', 'San Francisco, CA 94117']},
#    'phone': '+14154166989',
#    'display_phone': '(415) 416-6989',
#    'distance': 1854.0398960195314},
#   {'id': 'T3FbmF9qCFlAzNfOqpNTiA',
#    'alias': 'the-meat-house-san-francisco-2',
#    'name': 'The Meat House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/brfqJniAnqQkeJ-Ruzygig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-meat-house-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 11,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.7808037897, 'longitude': -122.464634533},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'location': {'address1': '4217 Geary Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94118',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4217 Geary Blvd', 'San Francisco, CA 94118']},
#    'phone': '+14157026565',
#    'display_phone': '(415) 702-6565',
#    'distance': 3322.1700442419724},
#   {'id': 'vu6PlPyKptsT6oEq50qOzA',
#    'alias': 'delarosa-san-francisco-3',
#    'name': 'Delarosa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UPdC4GWl7gqOLTgQcs14BA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/delarosa-san-francisco-3?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1109,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7856178857509,
#     'longitude': -122.404516608598},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '37 Yerba Buena Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['37 Yerba Buena Ln', 'San Francisco, CA 94103']},
#    'phone': '+14158727363',
#    'display_phone': '(415) 872-7363',
#    'distance': 3928.217335012105},
#   {'id': 'dglMkHYfCycYX3MX92oFxg',
#    'alias': 'the-dorian-san-francisco',
#    'name': 'The Dorian',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QnVZPmkzjXOnkCzULOisnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dorian-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 524,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.80065, 'longitude': -122.4365},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '2001 Chestnut St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2001 Chestnut St', 'San Francisco, CA 94123']},
#    'phone': '+14158142671',
#    'display_phone': '(415) 814-2671',
#    'distance': 4416.893029604373},
#   {'id': 'cL0q9S4bqwpbAN9ZKh-Zeg',
#    'alias': 'nara-restaurant-and-sake-bar-san-francisco',
#    'name': 'Nara Restaurant & Sake Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7zzlpJKaC9bndjuo2UIr6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nara-restaurant-and-sake-bar-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 951,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.7721665317965,
#     'longitude': -122.430675700307},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '518 Haight St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['518 Haight St', 'San Francisco, CA 94117']},
#    'phone': '+14156386124',
#    'display_phone': '(415) 638-6124',
#    'distance': 1351.6641305802066},
#   {'id': '9Z9EETl8fZIP4s9KOHr5kg',
#    'alias': 'um-ma-san-francisco-3',
#    'name': 'um.ma',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lpl_pHqVC-PBxXGldcZEug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/um-ma-san-francisco-3?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 79,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7655, 'longitude': -122.46608},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1220 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94122',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1220 9th Ave', 'San Francisco, CA 94122']},
#    'phone': '+14155665777',
#    'display_phone': '(415) 566-5777',
#    'distance': 2664.4699746595206},
#   {'id': 'ttarnopezxmp2ROB1N2PaA',
#    'alias': 'nopa-san-francisco',
#    'name': 'Nopa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Li0xXDEM78GMG1xCYgYYaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nopa-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 4986,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.77483, 'longitude': -122.43746},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '560 Divisadero St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['560 Divisadero St', 'San Francisco, CA 94117']},
#    'phone': '+14158648643',
#    'display_phone': '(415) 864-8643',
#    'distance': 1559.1831881623302},
#   {'id': 'ZN7x2duyVesVVzlhWJNamQ',
#    'alias': 'skool-san-francisco',
#    'name': 'Skool',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/47i057bRXAm_sIvA2obD5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/skool-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1701,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7685096967036,
#     'longitude': -122.402136325836},
#    'transactions': ['restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1725 Alameda St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1725 Alameda St', 'San Francisco, CA 94103']},
#    'phone': '+14152558800',
#    'display_phone': '(415) 255-8800',
#    'distance': 3132.4940753864485},
#   {'id': 'pKP6ikrLyM5Gtua13kVoUw',
#    'alias': 'izakaya-sozai-san-francisco',
#    'name': 'Izakaya Sozai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/04zZBEjVU_nWbvhChdNggQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-sozai-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2040,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.763879, 'longitude': -122.47413},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1500 Irving St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94122',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1500 Irving St', 'San Francisco, CA 94122']},
#    'phone': '+14157425122',
#    'display_phone': '(415) 742-5122',
#    'distance': 3329.071252002252},
#   {'id': 'PsY5DMHxa5iNX_nX0T-qPA',
#    'alias': 'kokkari-estiatorio-san-francisco',
#    'name': 'Kokkari Estiatorio',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7StMTfE2srlcIu2opeTb3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kokkari-estiatorio-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 4411,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.796996, 'longitude': -122.399661},
#    'transactions': ['pickup'],
#    'price': '$$$',
#    'location': {'address1': '200 Jackson St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['200 Jackson St', 'San Francisco, CA 94111']},
#    'phone': '+14159810983',
#    'display_phone': '(415) 981-0983',
#    'distance': 5153.879756630951},
#   {'id': '_zfxJqH3XZ65X8sNYVKGqg',
#    'alias': 'paina-lounge-and-restaurant-san-francisco',
#    'name': "Pa'ina Lounge & Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FF7NuQ0CTghoz5p36_2e_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paina-lounge-and-restaurant-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 553,
#    'categories': [{'alias': 'hawaiian', 'title': 'Hawaiian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7853553960108,
#     'longitude': -122.432332634926},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1865 Post St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1865 Post St', 'San Francisco, CA 94115']},
#    'phone': '+14158292642',
#    'display_phone': '(415) 829-2642',
#    'distance': 2743.321558600849},
#   {'id': 'WavvLdfdP6g8aZTtbBQHTw',
#    'alias': 'gary-danko-san-francisco',
#    'name': 'Gary Danko',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CAprIoeKQAYV9oUw9xBbmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gary-danko-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 5412,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.80587, 'longitude': -122.42058},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '800 N Point St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['800 N Point St', 'San Francisco, CA 94109']},
#    'phone': '+14157492060',
#    'display_phone': '(415) 749-2060',
#    'distance': 5191.341803207417},
#   {'id': '_EncdQezAzcShATMFXL0dA',
#    'alias': 'tropisueno-san-francisco-8',
#    'name': 'Tropisueno',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hUZgDmue1VRfvIXai6I0wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tropisueno-san-francisco-8?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 4261,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7853008468227,
#     'longitude': -122.403918653727},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '75 Yerba Buena Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['75 Yerba Buena Ln', 'San Francisco, CA 94103']},
#    'phone': '+14152430299',
#    'display_phone': '(415) 243-0299',
#    'distance': 3941.5902762189608},
#   {'id': 'h5ohkmv-UQiJTKFzxSS6RQ',
#    'alias': 'noosh-san-francisco',
#    'name': 'Noosh',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/htZmQ5FmRZjYRujcb2T_WA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noosh-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 177,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7880771447147,
#     'longitude': -122.43393894285},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2001 Fillmore St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2001 Fillmore St', 'San Francisco, CA 94115']},
#    'phone': '+14152315985',
#    'display_phone': '(415) 231-5985',
#    'distance': 3030.055075171354},
#   {'id': 'kqk5BoCJU59MC9fH0IB4wQ',
#    'alias': 'kin-khao-san-francisco-2',
#    'name': 'Kin Khao',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zHz6-HG5XuXSZJq2FvNmsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kin-khao-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1956,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7852278803726,
#     'longitude': -122.409348137336},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '55 Cyril Magnin St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['55 Cyril Magnin St', 'San Francisco, CA 94102']},
#    'phone': '+14153627456',
#    'display_phone': '(415) 362-7456',
#    'distance': 3604.326557361939},
#   {'id': '8skVQNkVBv90iiPtFeSpzw',
#    'alias': 'zero-zero-san-francisco',
#    'name': 'Zero Zero',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JB5XNOgdQHocE4nI9DHWkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zero-zero-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 3226,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.78163, 'longitude': -122.40204},
#    'transactions': ['restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '826 Folsom St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94107',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['826 Folsom St', 'San Francisco, CA 94107']},
#    'phone': '+14153488800',
#    'display_phone': '(415) 348-8800',
#    'distance': 3800.206476277323},
#   {'id': 'ey_UUXdDMUoO77QIF6SGaQ',
#    'alias': 'mensho-tokyo-san-francisco-2',
#    'name': 'Mensho Tokyo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FW8fWpjUC-LSju9liA_Kug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mensho-tokyo-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2032,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7866908459856,
#     'longitude': -122.414326295257},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '672 Geary St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['672 Geary St', 'San Francisco, CA 94102']},
#    'phone': '+14158008345',
#    'display_phone': '(415) 800-8345',
#    'distance': 3464.7984167587592},
#   {'id': 'Fe-YjAdSRLqDC2H_pqPcSw',
#    'alias': 'hinodeya-ramen-bar-san-francisco',
#    'name': 'Hinodeya Ramen Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rs6UpqUf1oycGk0NuLQXlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hinodeya-ramen-bar-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 929,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7861574638014,
#     'longitude': -122.430057115853},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1737 Buchanan St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1737 Buchanan St', 'San Francisco, CA 94115']},
#    'phone': '+14157570552',
#    'display_phone': '(415) 757-0552',
#    'distance': 2864.172030534964},
#   {'id': 'dY0Mc_PHH6nLENvWmVtwxQ',
#    'alias': 'daeho-kalbijjim-and-beef-soup-san-francisco-9',
#    'name': 'Daeho Kalbijjim & Beef Soup',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NjLR02YB4810aC8QDCDTXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daeho-kalbijjim-and-beef-soup-san-francisco-9?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 367,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.78601, 'longitude': -122.42858},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1620 Post St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1620 Post St', 'San Francisco, CA 94115']},
#    'phone': '+14155631388',
#    'display_phone': '(415) 563-1388',
#    'distance': 2863.096983817991},
#   {'id': 'o4x29HYKvEUf7Regrn-J9g',
#    'alias': 'troya-san-francisco-3',
#    'name': 'Troya',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MLHVzACARD-Q6H9DbnTG7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/troya-san-francisco-3?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 540,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7893743915288,
#     'longitude': -122.434076070785},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2125 Fillmore St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2125 Fillmore St', 'San Francisco, CA 94115']},
#    'phone': '+14155631000',
#    'display_phone': '(415) 563-1000',
#    'distance': 3173.1228071385012},
#   {'id': 'oT08T3Vpn1I7jDmrBBRMTw',
#    'alias': 'house-of-prime-rib-san-francisco',
#    'name': 'House of Prime Rib',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HLrjaMoAgYSac0vx71YpCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/house-of-prime-rib-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 6921,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.79338, 'longitude': -122.4225},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1906 Van Ness Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1906 Van Ness Ave', 'San Francisco, CA 94109']},
#    'phone': '+14158854605',
#    'display_phone': '(415) 885-4605',
#    'distance': 3819.642257655711},
#   {'id': 'WFgRFq_KxIs2fkYo1iD6Tg',
#    'alias': 'lers-ros-san-francisco-2',
#    'name': 'Lers Ros',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/R1NZEpF4b0INlulJudiAew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lers-ros-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2147,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.784703, 'longitude': -122.417566},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '730 Larkin St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['730 Larkin St', 'San Francisco, CA 94109']},
#    'phone': '+14159316917',
#    'display_phone': '(415) 931-6917',
#    'distance': 3122.9562838595198},
#   {'id': 'l7xUpaUBzsh32M7b8yWGfA',
#    'alias': 'myriad-gastropub-san-francisco',
#    'name': 'Myriad Gastropub',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wvTCIBwYUix2zPx4NOTydA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/myriad-gastropub-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 573,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.757248, 'longitude': -122.418733},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2491 Mission St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2491 Mission St', 'San Francisco, CA 94110']},
#    'phone': '+14155254335',
#    'display_phone': '(415) 525-4335',
#    'distance': 1609.3059724189864},
#   {'id': 'LjVlsV9tKGnv7e4Iyt9c5Q',
#    'alias': 'lark-san-francisco-2',
#    'name': 'Lark',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/R6YHvDguQXu-pClH2sCKUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lark-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 273,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.761243, 'longitude': -122.434248},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '4068 18th St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4068 18th St', 'San Francisco, CA 94114']},
#    'phone': '+14154004623',
#    'display_phone': '(415) 400-4623',
#    'distance': 197.0605128915999},
#   {'id': '-BKIqDQ3CawzwyN9kW1-FQ',
#    'alias': 'mangrove-kitchen-san-francisco',
#    'name': 'Mangrove Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bqfvFC466Qv42jv2V0GLtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mangrove-kitchen-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 185,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.77251, 'longitude': -122.43696},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '312 Divisadero St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['312 Divisadero St', 'San Francisco, CA 94117']},
#    'phone': '+14155526881',
#    'display_phone': '(415) 552-6881',
#    'distance': 1292.4569284214758},
#   {'id': 'Wcd6K6APT-yWVCSi4oq-kg',
#    'alias': 'kitchen-istanbul-san-francisco',
#    'name': 'Kitchen Istanbul',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YAjeBu1fTdR4tyT7-DPdWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitchen-istanbul-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 461,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.782849, 'longitude': -122.46321},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '349 Clement St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94118',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['349 Clement St', 'San Francisco, CA 94118']},
#    'phone': '+14157539479',
#    'display_phone': '(415) 753-9479',
#    'distance': 3389.7335007923343},
#   {'id': 'Y96P7pYNYya_bP-Ogun-0w',
#    'alias': 'ozaoza-san-francisco',
#    'name': 'OzaOza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mIe3lNzg_QMKBKKpJ5yD9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ozaoza-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 99,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 37.785801, 'longitude': -122.43015},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$$',
#    'location': {'address1': '1700 Post St',
#     'address2': 'Ste K,Fl 2',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1700 Post St',
#      'Ste K,Fl 2',
#      'San Francisco, CA 94115']},
#    'phone': '+14156744400',
#    'display_phone': '(415) 674-4400',
#    'distance': 2823.7040490712293},
#   {'id': 'HaAb_L9zVNLjJwrBkSf_Vw',
#    'alias': 'pier-market-seafood-restaurant-san-francisco',
#    'name': 'Pier Market Seafood Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oiWv-yEYYS62vOvFC97sTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pier-market-seafood-restaurant-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1910,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.8099386456994,
#     'longitude': -122.410550415516},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': 'Pier 39',
#     'address2': 'Ste 103',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94133',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['Pier 39', 'Ste 103', 'San Francisco, CA 94133']},
#    'phone': '+14159897437',
#    'display_phone': '(415) 989-7437',
#    'distance': 5908.750879956415},
#   {'id': 'r2jiJk3yivcLkWSSYELGcA',
#    'alias': 'tataki-san-francisco',
#    'name': 'Tataki',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fc3n53gUq5lZ_gD1VjUJ8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tataki-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1246,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7878390504557,
#     'longitude': -122.441227674274},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '2827 California St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2827 California St', 'San Francisco, CA 94115']},
#    'phone': '+14159311182',
#    'display_phone': '(415) 931-1182',
#    'distance': 3024.874051233535},
#   {'id': 'c0WpyZFR3EoEBKcoY2LZ3Q',
#    'alias': 'marlowe-san-francisco-2',
#    'name': 'Marlowe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wcnVYOjwK254JZod_2pXgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marlowe-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2663,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7783200510611,
#     'longitude': -122.396771288052},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '500 Brannan St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94107',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['500 Brannan St', 'San Francisco, CA 94107']},
#    'phone': '+14157771413',
#    'display_phone': '(415) 777-1413',
#    'distance': 3989.2680242711845},
#   {'id': 'Ffb9HJIrt4YPFCQIpBg6gw',
#    'alias': 'castagna-san-francisco',
#    'name': 'Castagna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6H8f983IWeNUee4PIAMYkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/castagna-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 385,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.80055, 'longitude': -122.4365},
#    'transactions': ['restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2015 Chestnut St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2015 Chestnut St', 'San Francisco, CA 94123']},
#    'phone': '+14154404290',
#    'display_phone': '(415) 440-4290',
#    'distance': 4414.10478819015},
#   {'id': '2oj_6uCp4DgVTJhYqEmBbA',
#    'alias': 'old-skool-cafe-san-francisco',
#    'name': 'Old Skool Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xk3xQ1bloHuotiF_N-yqzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/old-skool-cafe-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 538,
#    'categories': [{'alias': 'soulfood', 'title': 'Soul Food'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.734266, 'longitude': -122.390515},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1429 Mendell St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94124',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1429 Mendell St', 'San Francisco, CA 94124']},
#    'phone': '+14158228531',
#    'display_phone': '(415) 822-8531',
#    'distance': 5007.996587354394},
#   {'id': 'VPXezwmTETrwitrzj9BZPA',
#    'alias': 'dumpling-time-san-francisco',
#    'name': 'Dumpling Time',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Gs2DMOgxTWbCDq_ELSs2nA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dumpling-time-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1526,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7697533, 'longitude': -122.4022546},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '11 Division St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['11 Division St', 'San Francisco, CA 94103']},
#    'phone': '+14155254797',
#    'display_phone': '(415) 525-4797',
#    'distance': 3151.2428912681967}],
#  'total': 4300,
#  'region': {'center': {'longitude': -122.43644714355469,
#    'latitude': 37.76089938976322}}}

# %%
# Set up containers to capture the data
#iterations = 0
restaurants = []
restaurant_count = 0

while restaurant_count < 1000:
#     iterations += 1
    try:
        print(f'Attempting to make API order... Restaurant Count: {restaurant_count}')
        payload = {
            'term': 'restaurants',
            'location': 'san francisco',
            'limit': 50,
            'offset': restaurant_count
        }

        # make the api call
        response = requests.get(uri, params=payload, headers=headers)
        print(f'Status Code: {response.status_code}')

        # grab the data
        data = response.json()
        print(f'Restaurant data: {data.keys()}')

        # add the results to our restaurants list [0].concat([1, 2, 3]) -> [0,1 2, 3, 4]
        restaurants += data['businesses']

        # keep track of the current count that we can offset the api call by
        restaurant_count += 50
    except:
        print(' Mr.Fullsack.. I dont feel so good...something went wrong in kitchen... Giving up')
# Out:
# Attempting to make API order... Restaurant Count: 0
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 50
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 100
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 150
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 200
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 250
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 300
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 350
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 400
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 450
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 500
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 550
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 600
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 650
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 700
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 750
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 800
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 850
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 900
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 950
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])

# %%
# check the number of dictionary objects in list
len(restaurants)
# Out:
# 1000

# %%
# checking to see if the data is not duplicate
restaurant_names = []

for obj in restaurants:
    restaurant_names.append(obj['name'])

# %%
restaurant_unique = set(restaurant_names)
print('Number of unique restaurants:', len(restaurant_unique))
# Out:
# Number of unique restaurants: 969

# %%
# (NOTE: CONTAINS DUPLICATES)
pd.DataFrame(restaurants)
# Out:
#                                                alias  \
# 0              fog-harbor-fish-house-san-francisco-2
# 1                            the-house-san-francisco
# 2                    marufuku-ramen-sf-san-francisco
# 3                              beretta-san-francisco
# 4       farmhouse-kitchen-thai-cuisine-san-francisco
# 5                liholiho-yacht-club-san-francisco-2
# 6                               loló-san-francisco-4
# 7                             delarosa-san-francisco
# 8                      the-front-porch-san-francisco
# 9                  scomas-restaurant-san-francisco-3
# 10   tuba-authentic-turkish-restaurant-san-francisco
# 11                       suppenküche-san-francisco-2
{'alias': 'ramen', 'title': 'Ramen'}, {'alias...
# 26   [{'alias': 'greek', 'title': 'Greek'}, {'alias...
# 27   [{'alias': 'hawaiian', 'title': 'Hawaiian'}, {...
# 28   [{'alias': 'newamerican', 'title': 'American (...
# 29   [{'alias': 'cocktailbars', 'title': 'Cocktail ...
# ..                                                 ...
# 970  [{'alias': 'newamerican', 'title': 'American (...
# 971  [{'alias': 'poke', 'title': 'Poke'}, {'alias':...
# 972         [{'alias': 'chinese', 'title': 'Chinese'}]
# 973  [{'alias': 'newamerican', 'title': 'American (...
# 974  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...
# 975  [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 976  [{'alias': 'soulfood', 'title': 'Soul Food'}, ...
# 977  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 978             [{'alias': 'pizza', 'title': 'Pizza'}]
# 979  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 980  [{'alias': 'vietnamese', 'title': 'Vietnamese'...
# 981  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...
# 982  [{'alias': 'sportsbars', 'title': 'Sports Bars...
# 983  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...
# 984  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 985  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 986  [{'alias': 'breakfast_brunch', 'title': 'Break...
# 987           [{'alias': 'korean', 'title': 'Korean'}]
# 988  [{'alias': 'japanese', 'title': 'Japanese'}, {...
# 989  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...
# 990  [{'alias': 'venues', 'title': 'Venues & Event ...
# 991  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 992         [{'alias': 'mexican', 'title': 'Mexican'}]
# 993  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...
# 994  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 995  [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...
# 996  [{'alias': 'halal', 'title': 'Halal'}, {'alias...
# 997           [{'alias': 'french', 'title': 'French'}]
# 998  [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...
# 999  [{'alias': 'indpak', 'title': 'Indian'}, {'ali...
#
#                                            coordinates   display_phone  \
# 0    {'latitude': 37.809041, 'longitude': -122.410233}  (415) 421-2442
# 1      {'latitude': 37.79851, 'longitude': -122.40706}  (415) 986-8612
# 2    {'latitude': 37.785155, 'longitude': -122.432075}  (415) 872-9786
# 3      {'latitude': 37.75384, 'longitude': -122.42055}  (415) 695-1199
# 4    {'latitude': 37.7602179, 'longitude': -122.411...  (415) 814-2920
# 5      {'latitude': 37.78818, 'longitude': -122.41458}  (415) 440-5446
# 6    {'latitude': 37.7573462, 'longitude': -122.421...  (415) 643-5656
# 7    {'latitude': 37.800287, 'longitude': -122.4391...  (415) 673-7100
# 8      {'latitude': 37.7438, 'longitude': -122.422035}  (415) 695-7800
# 9    {'latitude': 37.808944, 'longitude': -122.418462}  (415) 771-4383
# 10   {'latitude': 37.7548912, 'longitude': -122.422...  (415) 826-8822
# 11   {'latitude': 37.7762603759766, 'longitude': -1...  (415) 252-9289
# 12   {'latitude': 37.7840954508032, 'longitude': -1...  (415) 441-9294
# 13     {'latitude': 37.79979, 'longitude': -122.40834}  (415) 398-3181
# 14   {'latitude': 37.782787322998, 'longitude': -12...  (415) 387-2147
# 15     {'latitude': 37.76367, 'longitude': -122.46896}  (415) 242-0828
# 16   {'latitude': 37.764096, 'longitude': -122.432574}  (415) 252-7500
# 17   {'latitude': 37.7757521780078, 'longitude': -1...  (415) 416-6989
# 18   {'latitude': 37.7808037897, 'longitude': -122....  (415) 702-6565
# 19   {'latitude': 37.7856178857509, 'longitude': -1...  (415) 872-7363
# 20      {'latitude': 37.80065, 'longitude': -122.4365}  (415) 814-2671
# 21   {'latitude': 37.7721665317965, 'longitude': -1...  (415) 638-6124
# 22      {'latitude': 37.7655, 'longitude': -122.46608}  (415) 566-5777
# 10   {'address1': '1007 Guerrero St', 'address2': '...
# 11   {'address1': '525 Laguna St', 'address2': '', ...
# 12   {'address1': '1560 Fillmore St', 'address2': N...
# 13   {'address1': '552 Green St', 'address2': '', '...
# 14   {'address1': '309 Clement St', 'address2': '',...
# 15   {'address1': '1031 Irving St', 'address2': '',...
# 16   {'address1': '3583 16th St', 'address2': '', '...
# 17   {'address1': '1785 Fulton St', 'address2': '',...
# 18   {'address1': '4217 Geary Blvd', 'address2': No...
# 19   {'address1': '37 Yerba Buena Ln', 'address2': ...
# 20   {'address1': '2001 Chestnut St', 'address2': '...
# 21   {'address1': '518 Haight St', 'address2': '', ...
# 22   {'address1': '1220 9th Ave', 'address2': None,...
# 23   {'address1': '560 Divisadero St', 'address2': ...
# 24   {'address1': '1725 Alameda St', 'address2': ''...
# 25   {'address1': '1500 Irving St', 'address2': Non...
# 26   {'address1': '200 Jackson St', 'address2': '',...
# 27   {'address1': '1865 Post St', 'address2': '', '...
# 28   {'address1': '800 N Point St', 'address2': '',...
# 29   {'address1': '75 Yerba Buena Ln', 'address2': ...
# ..                                                 ...
# 970  {'address1': '342 Howard St', 'address2': '', ...
# 971  {'address1': '800 Masonic Ave', 'address2': No...
# 972  {'address1': '1033 Irving St', 'address2': '',...
# 973  {'address1': '4800 3rd St', 'address2': '', 'a...
# 974  {'address1': '1424 Lombard St', 'address2': ''...
# 975  {'address1': '430 Columbus Ave', 'address2': '...
# 976  {'address1': '5176 3rd St', 'address2': '', 'a...
# 977  {'address1': '5423 Geary Blvd', 'address2': ''...
# 978  {'address1': '885 Brannan St', 'address2': '',...
# 979  {'address1': '5017 Geary Blvd', 'address2': ''...
# 980  {'address1': '2275 Market St', 'address2': '',...
# 981  {'address1': '474 3rd St', 'address2': None, '...
# 982  {'address1': '2800 Bayshore Blvd', 'address2':...
# 983  {'address1': '149 Noe St', 'address2': '', 'ad...
# 984  {'address1': '44 9th St', 'address2': '', 'add...
# 985  {'address1': '1200 9th Ave', 'address2': '', '...
# 986  {'address1': '2814 19th St', 'address2': '', '...
# 987  {'address1': '2001 Taraval St', 'address2': ''...
# 988  {'address1': '762 Valencia St', 'address2': ''...
# 989  {'address1': '533 Jones St', 'address2': '', '...
# 990  {'address1': '1345 Howard St', 'address2': '',...
# 991  {'address1': '680 2nd St', 'address2': '', 'ad...
# 992  {'address1': '4798 Mission St', 'address2': ''...
# 993  {'address1': '4243 18th St', 'address2': '', '...
# 994  {'address1': '1600 Folsom St', 'address2': '',...
# 995  {'address1': '3944 Geary Blvd', 'address2': No...
# 996  {'address1': '336 O'Farrell St', 'address2': '...
# 997  {'address1': '2500 Washington St', 'address2':...
# 998  {'address1': '2211 Mission St', 'address2': ''...
# 999  {'address1': '1007 Valencia St', 'address2': '...
#
#                                   name         phone price  rating  \
# 0                Fog Harbor Fish House  +14154212442    $$     4.0
# 1                            The House  +14159868612   $$$     4.5
# 2                    Marufuku Ramen SF  +14158729786    $$     4.5
# 997                         Chouquet's  +14153590075    $$     3.5
# 998                      Gracias Madre  +14156831346    $$     4.0
# 999                       Udupi Palace  +14159708000    $$     4.0
#
#      review_count                                transactions  \
# 0            5531                    [restaurant_reservation]
# 1            4650                    [restaurant_reservation]
# 2            2404                                          []
# 3            3500                    [restaurant_reservation]
# 4            2034  [pickup, delivery, restaurant_reservation]
# 5            2203                    [restaurant_reservation]
# 6            2072                    [restaurant_reservation]
# 7            1454                    [restaurant_reservation]
# 8            2719            [pickup, restaurant_reservation]
# 9            3567                    [restaurant_reservation]
# 10            987  [pickup, delivery, restaurant_reservation]
# 11           3086                    [restaurant_reservation]
# 12            758                    [restaurant_reservation]
# 13           3541                                          []
# 14           6619                                          []
# 15           6617                                          []
# 16           1776                          [pickup, delivery]
# 17            521                    [restaurant_reservation]
# 18             11  [pickup, delivery, restaurant_reservation]
# 19           1109                    [restaurant_reservation]
# 20            524                    [restaurant_reservation]
# 21            951                    [restaurant_reservation]
# 22             79                                          []
# 23           4986                                          []
# 24           1701            [pickup, restaurant_reservation]
# 25           2040                                          []
# 26           4411                                    [pickup]
# 27            553  [pickup, delivery, restaurant_reservation]
# 28           5412                                          []
# 29           4261                    [restaurant_reservation]
# ..            ...                                         ...
# 970          1918                                          []
# 971           156                          [pickup, delivery]
# 972           469                                          []
# 973           335                          [pickup, delivery]
# 974           130  [pickup, restaurant_reservation, delivery]
# 975          1472                    [restaurant_reservation]
# 976           402                                    [pickup]
# 977           615                          [pickup, delivery]
# 978            82                                          []
# 979          1449                          [pickup, delivery]
# 980           876                                    [pickup]
# 981           140                                          []
# 982          1039  [pickup, restaurant_reservation, delivery]
# 983           309                                          []
# 984           325  [pickup, restaurant_reservation, delivery]
# 985          1733                                    [pickup]
# 986          1332  [pickup, restaurant_reservation, delivery]
# 987           599                                          []
# 988          1163                                          []
# 989           408                                          []
# 990           138                                          []
# 991           325                                    [pickup]
# 992           922                                          []
# 993           305                          [pickup, delivery]
# 994           572                          [pickup, delivery]
# 995            35                          [pickup, delivery]
# 996           754                                  [delivery]
# 997           591                                          []
# 998          3126                          [pickup, delivery]
# 999          1330                          [pickup, delivery]
#
#                                                    url
# 0    https://www.yelp.com/biz/fog-harbor-fish-house...
# 1    https://www.yelp.com/biz/the-house-san-francis...
# 2    https://www.yelp.com/biz/marufuku-ramen-sf-san...
# 3    https://www.yelp.com/biz/beretta-san-francisco...
# 4    https://www.yelp.com/biz/farmhouse-kitchen-tha...
# 5    https://www.yelp.com/biz/liholiho-yacht-club-s...
# 6    https://www.yelp.com/biz/lol%C3%B3-san-francis...
# 7    https://www.yelp.com/biz/delarosa-san-francisc...
# 8    https://www.yelp.com/biz/the-front-porch-san-f...
# 9    https://www.yelp.com/biz/scomas-restaurant-san...
# 10   https://www.yelp.com/biz/tuba-authentic-turkis...
# 11   https://www.yelp.com/biz/suppenk%C3%BCche-san-...
# 12   https://www.yelp.com/biz/izakaya-kou-san-franc...
